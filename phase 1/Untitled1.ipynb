# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow import keras
import keras
from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D

# %%
data_dir = '/content/drive/MyDrive/مجلد بلا عنوان/Dataset_BUSI_with_GT'

# %%
# Working on 128 * 128 images, batch = 32 images each
batch_size = 32
img_height = 128
img_width = 128

# %%
# Training data -> 80%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 780 files belonging to 3 classes.
# Using 624 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 780 files belonging to 3 classes.
# Using 156 files for validation.

# %%
# Printing& storing classs names 'labels' to use later.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['benign', 'malignant', 'normal']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 128, 128, 3)
# (32,)

# %%
# Configrations for more performance, keeping images in memory, just for my Potato PC :')
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# Building CNN model using Conv2D 
num_classes = len(class_names)

model = Sequential([
  tf.keras.layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  tf.keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(128, 3, padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
 
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes, activation = 'softmax')
])

# %%
# Compiling 
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Printing model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 128, 128, 3)       0
#
#  conv2d (Conv2D)             (None, 128, 128, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 128)               1048704
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 1,146,531
# Trainable params: 1,146,531
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=30

history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 20/20 [==============================] - 27s 836ms/step - loss: 1.0775 - accuracy: 0.4872 - val_loss: 0.8939 - val_accuracy: 0.6090
# Epoch 2/30
# 20/20 [==============================] - 12s 612ms/step - loss: 0.9684 - accuracy: 0.5513 - val_loss: 0.9704 - val_accuracy: 0.6795
# Epoch 3/30
# 20/20 [==============================] - 12s 601ms/step - loss: 0.9517 - accuracy: 0.5833 - val_loss: 0.8245 - val_accuracy: 0.6154
# Epoch 4/30
# 20/20 [==============================] - 12s 601ms/step - loss: 0.8553 - accuracy: 0.6010 - val_loss: 0.8274 - val_accuracy: 0.6667
# Epoch 5/30
# 20/20 [==============================] - 12s 595ms/step - loss: 0.8215 - accuracy: 0.6506 - val_loss: 0.7642 - val_accuracy: 0.6987
# Epoch 6/30
# 20/20 [==============================] - 12s 595ms/step - loss: 0.7304 - accuracy: 0.7067 - val_loss: 0.7781 - val_accuracy: 0.6923
# Epoch 7/30
# 20/20 [==============================] - 13s 680ms/step - loss: 0.6724 - accuracy: 0.7163 - val_loss: 0.7775 - val_accuracy: 0.7372
# Epoch 8/30
# 20/20 [==============================] - 12s 611ms/step - loss: 0.5800 - accuracy: 0.7500 - val_loss: 0.7975 - val_accuracy: 0.6731
# Epoch 9/30
# 20/20 [==============================] - 18s 904ms/step - loss: 0.5509 - accuracy: 0.7740 - val_loss: 0.7271 - val_accuracy: 0.7436
# Epoch 10/30
# 20/20 [==============================] - 12s 600ms/step - loss: 0.4905 - accuracy: 0.7885 - val_loss: 0.8064 - val_accuracy: 0.6731
# Epoch 11/30
# 20/20 [==============================] - 12s 595ms/step - loss: 0.4534 - accuracy: 0.8157 - val_loss: 0.7647 - val_accuracy: 0.7308
# Epoch 12/30
# 20/20 [==============================] - 12s 596ms/step - loss: 0.3534 - accuracy: 0.8542 - val_loss: 0.9529 - val_accuracy: 0.7436
# Epoch 13/30
# 20/20 [==============================] - 12s 611ms/step - loss: 0.3140 - accuracy: 0.8782 - val_loss: 0.9036 - val_accuracy: 0.7244
# Epoch 14/30
# 20/20 [==============================] - 12s 599ms/step - loss: 0.2184 - accuracy: 0.9231 - val_loss: 0.9489 - val_accuracy: 0.7308
# Epoch 15/30
# 20/20 [==============================] - 12s 612ms/step - loss: 0.1629 - accuracy: 0.9439 - val_loss: 1.0573 - val_accuracy: 0.7692
# Epoch 16/30
# 20/20 [==============================] - 12s 597ms/step - loss: 0.1193 - accuracy: 0.9583 - val_loss: 1.0135 - val_accuracy: 0.7949
# Epoch 17/30
# 20/20 [==============================] - 12s 600ms/step - loss: 0.0788 - accuracy: 0.9776 - val_loss: 1.3589 - val_accuracy: 0.7821
# Epoch 18/30
# 20/20 [==============================] - 12s 599ms/step - loss: 0.0681 - accuracy: 0.9712 - val_loss: 1.2197 - val_accuracy: 0.7821
# Epoch 19/30
# 20/20 [==============================] - 12s 602ms/step - loss: 0.0495 - accuracy: 0.9840 - val_loss: 1.5937 - val_accuracy: 0.7372
# Epoch 20/30
# 20/20 [==============================] - 12s 602ms/step - loss: 0.0331 - accuracy: 0.9888 - val_loss: 1.5202 - val_accuracy: 0.7821
# Epoch 21/30
# 20/20 [==============================] - 12s 601ms/step - loss: 0.0469 - accuracy: 0.9824 - val_loss: 2.2170 - val_accuracy: 0.7564
# Epoch 22/30
# 20/20 [==============================] - 12s 597ms/step - loss: 0.0807 - accuracy: 0.9728 - val_loss: 1.3993 - val_accuracy: 0.7821
# Epoch 23/30
# 20/20 [==============================] - 12s 602ms/step - loss: 0.0321 - accuracy: 0.9888 - val_loss: 1.2075 - val_accuracy: 0.8013
# Epoch 24/30
# 20/20 [==============================] - 12s 602ms/step - loss: 0.0370 - accuracy: 0.9856 - val_loss: 1.4687 - val_accuracy: 0.8141
# Epoch 25/30
# 20/20 [==============================] - 12s 600ms/step - loss: 0.0307 - accuracy: 0.9920 - val_loss: 1.5099 - val_accuracy: 0.7692
# Epoch 26/30
# 20/20 [==============================] - 12s 601ms/step - loss: 0.0213 - accuracy: 0.9920 - val_loss: 1.6204 - val_accuracy: 0.7756
# Epoch 27/30
# 20/20 [==============================] - 12s 612ms/step - loss: 0.0239 - accuracy: 0.9936 - val_loss: 1.8081 - val_accuracy: 0.7756
# Epoch 28/30
# 20/20 [==============================] - 12s 601ms/step - loss: 0.0360 - accuracy: 0.9936 - val_loss: 1.6778 - val_accuracy: 0.7628
# Epoch 29/30
# 20/20 [==============================] - 12s 600ms/step - loss: 0.0730 - accuracy: 0.9808 - val_loss: 1.9594 - val_accuracy: 0.7564
# Epoch 30/30
# 20/20 [==============================] - 12s 599ms/step - loss: 0.0610 - accuracy: 0.9776 - val_loss: 1.4574 - val_accuracy: 0.7821

# %%
#Playing with subplot Visualizer, Accuracy vs Loss
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# data augmentation, 
data_augmentation = keras.Sequential(
  [
    tf.keras.layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
  ]
)

# %%
# Showing how data agumentation affects the same image
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
# new model using Dropout
model = Sequential([
  data_augmentation,
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
 tf.keras.layers.Dense(num_classes, activation = 'softmax')
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 128, 128, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 128, 128, 3)       0
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 16)      448
#
#  max_pooling2d_4 (MaxPooling  (None, 64, 64, 16)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 32)        4640
#
#  max_pooling2d_5 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  flatten_1 (Flatten)         (None, 16384)             0
#
#  dense_2 (Dense)             (None, 128)               2097280
#
#  dense_3 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 2,121,251
# Trainable params: 2,121,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 20/20 [==============================] - 13s 596ms/step - loss: 1.0215 - accuracy: 0.5337 - val_loss: 0.8762 - val_accuracy: 0.6474
# Epoch 2/20
# 20/20 [==============================] - 12s 582ms/step - loss: 0.9344 - accuracy: 0.5849 - val_loss: 0.8179 - val_accuracy: 0.6218
# Epoch 3/20
# 20/20 [==============================] - 12s 584ms/step - loss: 0.9035 - accuracy: 0.6234 - val_loss: 0.7986 - val_accuracy: 0.6603
# Epoch 4/20
# 20/20 [==============================] - 12s 584ms/step - loss: 0.8564 - accuracy: 0.6410 - val_loss: 0.7971 - val_accuracy: 0.6603
# Epoch 5/20
# 20/20 [==============================] - 12s 585ms/step - loss: 0.8278 - accuracy: 0.6266 - val_loss: 0.8015 - val_accuracy: 0.6795
# Epoch 6/20
# 20/20 [==============================] - 18s 921ms/step - loss: 0.7606 - accuracy: 0.6731 - val_loss: 0.9253 - val_accuracy: 0.6667
# Epoch 7/20
# 20/20 [==============================] - 17s 816ms/step - loss: 0.7328 - accuracy: 0.6891 - val_loss: 0.8572 - val_accuracy: 0.6667
# Epoch 8/20
# 20/20 [==============================] - 12s 585ms/step - loss: 0.7314 - accuracy: 0.6827 - val_loss: 0.7881 - val_accuracy: 0.6795
# Epoch 9/20
# 20/20 [==============================] - 12s 586ms/step - loss: 0.7216 - accuracy: 0.6971 - val_loss: 0.7910 - val_accuracy: 0.6731
# Epoch 10/20
# 20/20 [==============================] - 12s 596ms/step - loss: 0.6981 - accuracy: 0.7019 - val_loss: 0.7748 - val_accuracy: 0.7115
# Epoch 11/20
# 20/20 [==============================] - 12s 587ms/step - loss: 0.6517 - accuracy: 0.7163 - val_loss: 1.1267 - val_accuracy: 0.6667
# Epoch 12/20
# 20/20 [==============================] - 12s 583ms/step - loss: 0.6694 - accuracy: 0.6987 - val_loss: 0.7787 - val_accuracy: 0.7308
# Epoch 13/20
# 20/20 [==============================] - 12s 586ms/step - loss: 0.6467 - accuracy: 0.7115 - val_loss: 0.7452 - val_accuracy: 0.7115
# Epoch 14/20
# 20/20 [==============================] - 12s 585ms/step - loss: 0.6067 - accuracy: 0.7388 - val_loss: 0.8372 - val_accuracy: 0.7244
# Epoch 15/20
# 20/20 [==============================] - 12s 585ms/step - loss: 0.5866 - accuracy: 0.7532 - val_loss: 0.9024 - val_accuracy: 0.6795
# Epoch 16/20
# 20/20 [==============================] - 12s 597ms/step - loss: 0.6262 - accuracy: 0.7324 - val_loss: 0.8078 - val_accuracy: 0.7115
# Epoch 17/20
# 20/20 [==============================] - 12s 588ms/step - loss: 0.5967 - accuracy: 0.7372 - val_loss: 1.1184 - val_accuracy: 0.6859
# Epoch 18/20
# 20/20 [==============================] - 12s 585ms/step - loss: 0.5709 - accuracy: 0.7420 - val_loss: 0.8203 - val_accuracy: 0.7179
# Epoch 19/20
# 20/20 [==============================] - 12s 583ms/step - loss: 0.5430 - accuracy: 0.7724 - val_loss: 0.8798 - val_accuracy: 0.7115
# Epoch 20/20
# 20/20 [==============================] - 12s 584ms/step - loss: 0.5517 - accuracy: 0.7628 - val_loss: 0.7617 - val_accuracy: 0.7308

# %%
# Plotting again to see new results visualized:
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Working on 128 * 128 images, batch = 32 images each
batch_size = 32
img_height = 224
img_width = 224

# %%
# Training data -> 80%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 780 files belonging to 3 classes.
# Using 624 files for training.

# %%
import numpy as np
from keras import layers
import keras.applications.resnet
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential

import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools
# %matplotlib inline

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 780 files belonging to 3 classes.
# Using 156 files for validation.

# %%
def build_model(backbone, lr=1e-4):
    model = Sequential()
    model.add(backbone)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dropout(0.5))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(num_classes, activation='softmax'))
    
    
    model.compile(
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        optimizer='adam',
        metrics=['accuracy']
    )
    
    return model

# %%
from keras.applications.densenet import DenseNet201, DenseNet121

K.clear_session()
gc.collect()

resnet = DenseNet201(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)


 


model = build_model(resnet ,lr = 1e-4)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 7, 7, 1920)        18321984
#
#  global_average_pooling2d (G  (None, 1920)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1920)              0
#
#  batch_normalization (BatchN  (None, 1920)             7680
#  ormalization)
#
#  dense (Dense)               (None, 3)                 5763
#
# =================================================================
# Total params: 18,335,427
# Trainable params: 18,102,531
# Non-trainable params: 232,896
# _________________________________________________________________

# %%
epochs = 5
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
#  8/20 [===========>..................] - ETA: 7:47 - loss: 1.0478 - accuracy: 0.5742
